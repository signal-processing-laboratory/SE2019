# %% [markdown]
# # Regressão do banco de dados Carros
#
# Autores: Natanael Junior (natmourajr@lps.ufrj.br), Vinicius Mello (viniciusdsmello@poli.ufrj.br) e Pedro Lisboa (pedrohblisboa@gmail.com)
#
# LPS - Laboratório de Processamento de Sinais
# <center><img src="../data/logo_lps.jpg"></center>

# %%
# %time
import os
import numpy as np
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# CPU times: user 4 µs, sys: 2 µs, total: 6 µs
# Wall time: 11.7 µs

# %%
# %time
df = pd.read_csv('../data/cars.csv')
# Out:
# CPU times: user 3 µs, sys: 2 µs, total: 5 µs
# Wall time: 9.78 µs

# %%
df.head()
# Out:
#    age  gender  avr_per_day   debt  income  price
# 0   28       0           23      0    4099    620
# 1   26       0           27      0    2677   1792
# 2   30       1           58  41576    6215  27754
# 3   26       1           25  43172    7626  28256
# 4   20       1           17   6979    8071   4438

# %% [markdown]
# ### Informações sobre o banco de dados
# Os dados são dados simulados contento:
#  - age: idade do comprador
#  - gender: genero
#  - avr_per_day: quantidade de milhas média rodadas em um dia
#  - debt: quantidade de débito que o comprador tem
#  - income: renda mensal
#  - price: valor pago

# %%
col_list = df.columns.tolist()
col_list.remove('price')
data = df[col_list]
trgt = df['price']
trgt = trgt[:,np.newaxis]

# %% [markdown]
# ### Obs:
# a rede neural trabalha com matemática vetorial, ou seja, precisa de matrizes em sua saída! Por isso, o ```np.newaxis```

# %%
from sklearn.model_selection import KFold
from sklearn.preprocessing import MinMaxScaler

from keras.models import Sequential
from keras.layers import Dense

nfolds = 4
foldshandler = KFold(n_splits=nfolds)

for ifold,(trainId,testId) in enumerate(foldshandler.split(data)):
    if ifold != 0: break
        
    data_scaler = MinMaxScaler().fit(data.values[trainId])
    trgt_scaler = MinMaxScaler().fit(trgt[trainId])
    
    norm_data = data_scaler.transform(data)
    norm_trgt = trgt_scaler.transform(trgt)
    
    model = Sequential()
    model.add(Dense(12, input_dim=5, kernel_initializer='normal', activation='relu'))
    model.add(Dense(8, activation='relu'))
    model.add(Dense(1, activation='linear'))
    
    model.compile(loss='mse', optimizer='adam', metrics=['mse','mae'])
    model.summary()
    
    history = model.fit(norm_data, norm_trgt, epochs=150, batch_size=50,  verbose=1, validation_split=0.2)
# Out:
# Using TensorFlow backend.
# /home/natmourajr/.virtualenvs/ieg/lib/python3.5/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# /home/natmourajr/.virtualenvs/ieg/lib/python3.5/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 12)                72
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 104
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 185
# Trainable params: 185
# Non-trainable params: 0
# _________________________________________________________________
# Train on 770 samples, validate on 193 samples
# Epoch 1/150
# 770/770 [==============================] - 0s 477us/step - loss: 0.1723 - mean_squared_error: 0.1723 - mean_absolute_error: 0.3113 - val_loss: 0.1301 - val_mean_squared_error: 0.1301 - val_mean_absolute_error: 0.2667
# Epoch 2/150
# 770/770 [==============================] - 0s 22us/step - loss: 0.1014 - mean_squared_error: 0.1014 - mean_absolute_error: 0.2402 - val_loss: 0.0772 - val_mean_squared_error: 0.0772 - val_mean_absolute_error: 0.2168
# Epoch 3/150
# 770/770 [==============================] - 0s 30us/step - loss: 0.0126 - mean_squared_error: 0.0126 - mean_absolute_error: 0.0822 - val_loss: 0.0133 - val_mean_squared_error: 0.0133 - val_mean_absolute_error: 0.0879
# Epoch 83/150
# 770/770 [==============================] - 0s 31us/step - loss: 0.0124 - mean_squared_error: 0.0124 - mean_absolute_error: 0.0803 - val_loss: 0.0130 - val_mean_squared_error: 0.0130 - val_mean_absolute_error: 0.0904
# Epoch 84/150
# 770/770 [==============================] - 0s 36us/step - loss: 0.0125 - mean_squared_error: 0.0125 - mean_absolute_error: 0.0818 - val_loss: 0.0131 - val_mean_squared_error: 0.0131 - val_mean_absolute_error: 0.0891
# Epoch 85/150
# 770/770 [==============================] - 0s 36us/step - loss: 0.0124 - mean_squared_error: 0.0124 - mean_absolute_error: 0.0814 - val_loss: 0.0132 - val_mean_squared_error: 0.0132 - val_mean_absolute_error: 0.0883
# Epoch 86/150
# 770/770 [==============================] - 0s 37us/step - loss: 0.0125 - mean_squared_error: 0.0125 - mean_absolute_error: 0.0808 - val_loss: 0.0130 - val_mean_squared_error: 0.0130 - val_mean_absolute_error: 0.0889
# Epoch 87/150
# 770/770 [==============================] - 0s 33us/step - loss: 0.0123 - mean_squared_error: 0.0123 - mean_absolute_error: 0.0799 - val_loss: 0.0128 - val_mean_squared_error: 0.0128 - val_mean_absolute_error: 0.0879
# Epoch 88/150
# 770/770 [==============================] - 0s 36us/step - loss: 0.0122 - mean_squared_error: 0.0122 - mean_absolute_error: 0.0800 - val_loss: 0.0128 - val_mean_squared_error: 0.0128 - val_mean_absolute_error: 0.0894
# Epoch 89/150
# 770/770 [==============================] - 0s 31us/step - loss: 0.0123 - mean_squared_error: 0.0123 - mean_absolute_error: 0.0805 - val_loss: 0.0132 - val_mean_squared_error: 0.0132 - val_mean_absolute_error: 0.0881
# Epoch 90/150
# 770/770 [==============================] - 0s 36us/step - loss: 0.0122 - mean_squared_error: 0.0122 - mean_absolute_error: 0.0799 - val_loss: 0.0128 - val_mean_squared_error: 0.0128 - val_mean_absolute_error: 0.0881
# Epoch 91/150
# 770/770 [==============================] - 0s 30us/step - loss: 0.0122 - mean_squared_error: 0.0122 - mean_absolute_error: 0.0793 - val_loss: 0.0127 - val_mean_squared_error: 0.0127 - val_mean_absolute_error: 0.0895
# Epoch 92/150
# 770/770 [==============================] - 0s 27us/step - loss: 0.0122 - mean_squared_error: 0.0122 - mean_absolute_error: 0.0810 - val_loss: 0.0135 - val_mean_squared_error: 0.0135 - val_mean_absolute_error: 0.0885
# Epoch 93/150
# 770/770 [==============================] - 0s 32us/step - loss: 0.0123 - mean_squared_error: 0.0123 - mean_absolute_error: 0.0805 - val_loss: 0.0127 - val_mean_squared_error: 0.0127 - val_mean_absolute_error: 0.0885
# Epoch 94/150
# 770/770 [==============================] - 0s 34us/step - loss: 0.0121 - mean_squared_error: 0.0121 - mean_absolute_error: 0.0792 - val_loss: 0.0127 - val_mean_squared_error: 0.0127 - val_mean_absolute_error: 0.0885
# Epoch 95/150
# 770/770 [==============================] - 0s 30us/step - loss: 0.0121 - mean_squared_error: 0.0121 - mean_absolute_error: 0.0805 - val_loss: 0.0133 - val_mean_squared_error: 0.0133 - val_mean_absolute_error: 0.0869
# Epoch 109/150
# 770/770 [==============================] - 0s 31us/step - loss: 0.0122 - mean_squared_error: 0.0122 - mean_absolute_error: 0.0801 - val_loss: 0.0126 - val_mean_squared_error: 0.0126 - val_mean_absolute_error: 0.0874
# Epoch 110/150
# 770/770 [==============================] - 0s 34us/step - loss: 0.0120 - mean_squared_error: 0.0120 - mean_absolute_error: 0.0786 - val_loss: 0.0124 - val_mean_squared_error: 0.0124 - val_mean_absolute_error: 0.0878
# Epoch 111/150
# 770/770 [==============================] - 0s 37us/step - loss: 0.0118 - mean_squared_error: 0.0118 - mean_absolute_error: 0.0784 - val_loss: 0.0126 - val_mean_squared_error: 0.0126 - val_mean_absolute_error: 0.0864
# Epoch 112/150
# 770/770 [==============================] - 0s 36us/step - loss: 0.0119 - mean_squared_error: 0.0119 - mean_absolute_error: 0.0787 - val_loss: 0.0125 - val_mean_squared_error: 0.0125 - val_mean_absolute_error: 0.0884
# Epoch 113/150
# 770/770 [==============================] - 0s 34us/step - loss: 0.0121 - mean_squared_error: 0.0121 - mean_absolute_error: 0.0791 - val_loss: 0.0125 - val_mean_squared_error: 0.0125 - val_mean_absolute_error: 0.0877
# Epoch 114/150
# 770/770 [==============================] - 0s 50us/step - loss: 0.0118 - mean_squared_error: 0.0118 - mean_absolute_error: 0.0780 - val_loss: 0.0124 - val_mean_squared_error: 0.0124 - val_mean_absolute_error: 0.0872
# Epoch 115/150
# 770/770 [==============================] - 0s 34us/step - loss: 0.0119 - mean_squared_error: 0.0119 - mean_absolute_error: 0.0782 - val_loss: 0.0124 - val_mean_squared_error: 0.0124 - val_mean_absolute_error: 0.0873
# Epoch 116/150
# 770/770 [==============================] - 0s 28us/step - loss: 0.0120 - mean_squared_error: 0.0120 - mean_absolute_error: 0.0796 - val_loss: 0.0128 - val_mean_squared_error: 0.0128 - val_mean_absolute_error: 0.0862
# Epoch 117/150
# 770/770 [==============================] - 0s 34us/step - loss: 0.0117 - mean_squared_error: 0.0117 - mean_absolute_error: 0.0781 - val_loss: 0.0123 - val_mean_squared_error: 0.0123 - val_mean_absolute_error: 0.0863
# Epoch 118/150
# 770/770 [==============================] - 0s 29us/step - loss: 0.0118 - mean_squared_error: 0.0118 - mean_absolute_error: 0.0787 - val_loss: 0.0124 - val_mean_squared_error: 0.0124 - val_mean_absolute_error: 0.0865
# Epoch 119/150
# 770/770 [==============================] - 0s 31us/step - loss: 0.0118 - mean_squared_error: 0.0118 - mean_absolute_error: 0.0787 - val_loss: 0.0126 - val_mean_squared_error: 0.0126 - val_mean_absolute_error: 0.0861
# Epoch 120/150
# 770/770 [==============================] - 0s 35us/step - loss: 0.0118 - mean_squared_error: 0.0118 - mean_absolute_error: 0.0787 - val_loss: 0.0126 - val_mean_squared_error: 0.0126 - val_mean_absolute_error: 0.0859
# Epoch 121/150
# 770/770 [==============================] - 0s 28us/step - loss: 0.0118 - mean_squared_error: 0.0118 - mean_absolute_error: 0.0783 - val_loss: 0.0123 - val_mean_squared_error: 0.0123 - val_mean_absolute_error: 0.0860
# Epoch 122/150
# 770/770 [==============================] - 0s 29us/step - loss: 0.0117 - mean_squared_error: 0.0117 - mean_absolute_error: 0.0783 - val_loss: 0.0124 - val_mean_squared_error: 0.0124 - val_mean_absolute_error: 0.0861
# Epoch 123/150
# 770/770 [==============================] - 0s 29us/step - loss: 0.0117 - mean_squared_error: 0.0117 - mean_absolute_error: 0.0783 - val_loss: 0.0122 - val_mean_squared_error: 0.0122 - val_mean_absolute_error: 0.0865
# Epoch 124/150
# 770/770 [==============================] - 0s 28us/step - loss: 0.0117 - mean_squared_error: 0.0117 - mean_absolute_error: 0.0783 - val_loss: 0.0124 - val_mean_squared_error: 0.0124 - val_mean_absolute_error: 0.0858
# Epoch 125/150
# 770/770 [==============================] - 0s 40us/step - loss: 0.0120 - mean_squared_error: 0.0120 - mean_absolute_error: 0.0789 - val_loss: 0.0125 - val_mean_squared_error: 0.0125 - val_mean_absolute_error: 0.0889
# Epoch 126/150
# 770/770 [==============================] - 0s 37us/step - loss: 0.0118 - mean_squared_error: 0.0118 - mean_absolute_error: 0.0785 - val_loss: 0.0125 - val_mean_squared_error: 0.0125 - val_mean_absolute_error: 0.0859
# Epoch 127/150
# 770/770 [==============================] - 0s 42us/step - loss: 0.0117 - mean_squared_error: 0.0117 - mean_absolute_error: 0.0785 - val_loss: 0.0124 - val_mean_squared_error: 0.0124 - val_mean_absolute_error: 0.0853
# Epoch 128/150
# 770/770 [==============================] - 0s 40us/step - loss: 0.0117 - mean_squared_error: 0.0117 - mean_absolute_error: 0.0778 - val_loss: 0.0123 - val_mean_squared_error: 0.0123 - val_mean_absolute_error: 0.0859
# Epoch 129/150
# 770/770 [==============================] - 0s 36us/step - loss: 0.0118 - mean_squared_error: 0.0118 - mean_absolute_error: 0.0784 - val_loss: 0.0128 - val_mean_squared_error: 0.0128 - val_mean_absolute_error: 0.0857
# Epoch 130/150
# 770/770 [==============================] - 0s 34us/step - loss: 0.0117 - mean_squared_error: 0.0117 - mean_absolute_error: 0.0783 - val_loss: 0.0122 - val_mean_squared_error: 0.0122 - val_mean_absolute_error: 0.0860
# Epoch 131/150
# 770/770 [==============================] - 0s 27us/step - loss: 0.0116 - mean_squared_error: 0.0116 - mean_absolute_error: 0.0784 - val_loss: 0.0126 - val_mean_squared_error: 0.0126 - val_mean_absolute_error: 0.0852
# Epoch 132/150
# 770/770 [==============================] - 0s 30us/step - loss: 0.0118 - mean_squared_error: 0.0118 - mean_absolute_error: 0.0784 - val_loss: 0.0122 - val_mean_squared_error: 0.0122 - val_mean_absolute_error: 0.0874
# Epoch 133/150
# 770/770 [==============================] - 0s 31us/step - loss: 0.0117 - mean_squared_error: 0.0117 - mean_absolute_error: 0.0782 - val_loss: 0.0122 - val_mean_squared_error: 0.0122 - val_mean_absolute_error: 0.0848
# Epoch 134/150
# 770/770 [==============================] - 0s 27us/step - loss: 0.0116 - mean_squared_error: 0.0116 - mean_absolute_error: 0.0784 - val_loss: 0.0125 - val_mean_squared_error: 0.0125 - val_mean_absolute_error: 0.0855
# Epoch 135/150
# 770/770 [==============================] - 0s 29us/step - loss: 0.0118 - mean_squared_error: 0.0118 - mean_absolute_error: 0.0785 - val_loss: 0.0121 - val_mean_squared_error: 0.0121 - val_mean_absolute_error: 0.0865
# Epoch 136/150
# 770/770 [==============================] - 0s 27us/step - loss: 0.0117 - mean_squared_error: 0.0117 - mean_absolute_error: 0.0777 - val_loss: 0.0122 - val_mean_squared_error: 0.0122 - val_mean_absolute_error: 0.0872
# Epoch 137/150
# 770/770 [==============================] - 0s 32us/step - loss: 0.0120 - mean_squared_error: 0.0120 - mean_absolute_error: 0.0812 - val_loss: 0.0134 - val_mean_squared_error: 0.0134 - val_mean_absolute_error: 0.0871
# Epoch 138/150
# 770/770 [==============================] - 0s 26us/step - loss: 0.0117 - mean_squared_error: 0.0117 - mean_absolute_error: 0.0790 - val_loss: 0.0124 - val_mean_squared_error: 0.0124 - val_mean_absolute_error: 0.0879
# Epoch 139/150
# 770/770 [==============================] - 0s 28us/step - loss: 0.0116 - mean_squared_error: 0.0116 - mean_absolute_error: 0.0776 - val_loss: 0.0122 - val_mean_squared_error: 0.0122 - val_mean_absolute_error: 0.0856
# Epoch 140/150
# 770/770 [==============================] - 0s 30us/step - loss: 0.0115 - mean_squared_error: 0.0115 - mean_absolute_error: 0.0776 - val_loss: 0.0120 - val_mean_squared_error: 0.0120 - val_mean_absolute_error: 0.0851
# Epoch 141/150
# 770/770 [==============================] - 0s 26us/step - loss: 0.0119 - mean_squared_error: 0.0119 - mean_absolute_error: 0.0786 - val_loss: 0.0121 - val_mean_squared_error: 0.0121 - val_mean_absolute_error: 0.0858
# Epoch 142/150
# 770/770 [==============================] - 0s 41us/step - loss: 0.0120 - mean_squared_error: 0.0120 - mean_absolute_error: 0.0782 - val_loss: 0.0122 - val_mean_squared_error: 0.0122 - val_mean_absolute_error: 0.0872
# Epoch 143/150
# 770/770 [==============================] - 0s 41us/step - loss: 0.0115 - mean_squared_error: 0.0115 - mean_absolute_error: 0.0778 - val_loss: 0.0121 - val_mean_squared_error: 0.0121 - val_mean_absolute_error: 0.0849
# Epoch 144/150
# 770/770 [==============================] - 0s 38us/step - loss: 0.0116 - mean_squared_error: 0.0116 - mean_absolute_error: 0.0778 - val_loss: 0.0125 - val_mean_squared_error: 0.0125 - val_mean_absolute_error: 0.0853
# Epoch 145/150
# 770/770 [==============================] - 0s 36us/step - loss: 0.0116 - mean_squared_error: 0.0116 - mean_absolute_error: 0.0775 - val_loss: 0.0122 - val_mean_squared_error: 0.0122 - val_mean_absolute_error: 0.0844
# Epoch 146/150
# 770/770 [==============================] - 0s 27us/step - loss: 0.0117 - mean_squared_error: 0.0117 - mean_absolute_error: 0.0777 - val_loss: 0.0121 - val_mean_squared_error: 0.0121 - val_mean_absolute_error: 0.0854
# Epoch 147/150
# 770/770 [==============================] - 0s 30us/step - loss: 0.0117 - mean_squared_error: 0.0117 - mean_absolute_error: 0.0779 - val_loss: 0.0123 - val_mean_squared_error: 0.0123 - val_mean_absolute_error: 0.0868
# Epoch 148/150
# 770/770 [==============================] - 0s 29us/step - loss: 0.0117 - mean_squared_error: 0.0117 - mean_absolute_error: 0.0779 - val_loss: 0.0121 - val_mean_squared_error: 0.0121 - val_mean_absolute_error: 0.0861
# Epoch 149/150
# 770/770 [==============================] - 0s 27us/step - loss: 0.0114 - mean_squared_error: 0.0114 - mean_absolute_error: 0.0770 - val_loss: 0.0121 - val_mean_squared_error: 0.0121 - val_mean_absolute_error: 0.0846
# Epoch 150/150
# 770/770 [==============================] - 0s 29us/step - loss: 0.0115 - mean_squared_error: 0.0115 - mean_absolute_error: 0.0769 - val_loss: 0.0120 - val_mean_squared_error: 0.0120 - val_mean_absolute_error: 0.0864

# %% [markdown]
# Mostrar a evolução do treinamento

# %%
print(history.history.keys())

fig = plt.figure(figsize=(6,6))

ax = plt.subplot(1,1,1)

ax.plot(history.history['loss'])
ax.plot(history.history['val_loss'])
ax.set_title('Model Loss')
ax.set_ylabel('Loss')
ax.set_xlabel('epoch')
ax.legend(['train', 'validation'], loc='best')
ax.grid()
# Out:
# dict_keys(['val_mean_squared_error', 'val_mean_absolute_error', 'loss', 'mean_squared_error', 'val_loss', 'mean_absolute_error'])

# %%
fig = plt.figure(figsize=(6,6))
ax = plt.subplot(1,1,1)

pred_trgt = model.predict(norm_data)

ax.plot(pred_trgt[trainId],norm_trgt[trainId],'bo')
ax.plot(pred_trgt[testId],norm_trgt[testId],'ro')
ax.set_title('Scatter plot: Target vs Output')
ax.set_ylabel('Target')
ax.set_xlabel('Output')
# Out:
# Text(0.5, 0, 'Output')

# %%
df_out = pd.DataFrame(np.append(norm_trgt,pred_trgt,axis=1), columns=['target','output'])

# %%
sns.jointplot(x=df_out['output'], y=df_out['target'], kind="hex", color="#4CB391",height=10);

# %%
hm = sns.heatmap(df_out.corr(),annot = True, linewidths=.5, cmap='Blues')

# %%
sns.lmplot(x = 'output', y = 'target', data = df_out,
          scatter_kws = {'alpha':0.1},);

# %%
fig = plt.figure(figsize=(6,3))

n_bins = 20
ax = plt.subplot(1,2,1)

mse_values = (df_out['target'].values - df_out['output'].values)**2

bins = np.linspace(mse_values.min(),mse_values.max(),n_bins)
n, bins, patches = ax.hist(mse_values,bins=bins, density=True)
ax.set_title('(Target-Output)**2 Error Dist')
ax.set_ylabel('Probability')
ax.set_xlabel('Possible Values')
ax.grid()

ax = plt.subplot(1,2,2)

mae_values = (df_out['target'].values - df_out['output'].values)

bins = np.linspace(mae_values.min(),mae_values.max(),n_bins)
n, bins, patches = ax.hist(mae_values,bins=bins, density=True)
ax.set_title('(Target-Output) Error Dist')
ax.set_ylabel('Probability')
ax.set_xlabel('Possible Values')
ax.grid()

# %% [markdown]
# Podemos estimar o perfil de compra de um usuário ficticio.

# %%
new_data = np.array([[30, 0, 26, 10, 4000]])
norm_new_data = data_scaler.transform(new_data)
predicted = model.predict(norm_new_data)
print('Data: ', new_data, ' Price: ',trgt_scaler.inverse_transform(predicted))
# Out:
# Data:  [[  30    0   26   10 4000]]  Price:  [[5728.5156]]
